# %%
import talib
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
data = yf.download("RELIANCE.NS",start="2022-2-1",end="2023-1-19")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data['SMA_100'] =talib.SMA(data['Close'],50)

# %%
plt.plot(data['Close'])
plt.plot(data['SMA_100'])

# %%
data['EMA_100']=talib.EMA(data['Close'],100)
data.iloc[100:]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-05-26  137.389999  144.339996  137.139999  143.779999  143.342773
# 2022-05-27  145.389999  149.679993  145.259995  149.639999  149.184952
# 2022-05-31  149.070007  150.660004  146.839996  148.839996  148.387390
# 2022-06-01  149.899994  151.740005  147.679993  148.710007  148.257797
# 2022-06-02  147.830002  151.270004  146.860001  151.210007  150.750183
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.860001
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  130.029999
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  126.040001
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.610001
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.929993
#
#                Volume     SMA_100     EMA_100
# Date
# 2022-05-26   90601500  160.794401  163.965610
# ...

# %%
plt.plot(data['Close'])
plt.plot(data['EMA_100'])

# %%
data['RSI'] = talib.RSI(data['Close'])

# %%
fig,axs = plt.subplots(2,1,gridspec_kw={"height_ratios":[3,1]},figsize=(10,6))
axs[0].plot(data['Close'])
axs[1].axhline(y=70,color="r",linestyle="--")
axs[1].axhline(y=30,color="g",linestyle="--")
axs[1].plot(data['RSI'],color='orange')

# %%
data['Linear Reg']=talib.LINEARREG(data['Close'],100)

# %%
plt.plot(data['Close'])
plt.plot(data['Linear Reg'])

# %%
data = yf.download("GS",start="2021-1-1")

macd,macd_signal,macd_hist = talib.MACD(data['Close'])
c=["red" if cl<0 else "green" for cl in macd_hist]

fig,axs = plt.subplots(2,1,gridspec_kw={"height_ratios":[3,1]},figsize=(10,6))
axs[0].plot(data['Close'])

axs[1].plot(macd,'b-')
axs[1].plot(macd_signal,'--',color='orange')
axs[1].bar(macd_hist.index,macd_hist,color=c)
# Out:
# [*********************100%***********************]  1 of 1 completed
# <BarContainer object of 503 artists>

# %%
talib.get_functions()
# Out:
# ['HT_DCPERIOD',
#  'HT_DCPHASE',
#  'HT_PHASOR',
#  'HT_SINE',
#  'HT_TRENDMODE',
#  'ADD',
#  'DIV',
#  'MAX',
#  'MAXINDEX',
#  'MIN',
#  'MININDEX',
#  'MINMAX',
#  'MINMAXINDEX',
#  'MULT',
#  'SUB',
#  'SUM',
#  'ACOS',
#  'ASIN',
#  'ATAN',
#  'CEIL',
#  'COS',
#  'COSH',
#  'EXP',
#  'FLOOR',
#  'LN',
#  'LOG10',
#  'SIN',
#  'SINH',
#  'SQRT',
#  'TAN',
#  'TANH',
#  'ADX',
#  'ADXR',
#  'APO',
#  'AROON',
#  'AROONOSC',
#  'BOP',
#  'CCI',
#  'CMO',
#  'DX',
#  'MACD',
#  'MACDEXT',
#  'MACDFIX',
#  'MFI',
#  'MINUS_DI',
#  'MINUS_DM',
#  'MOM',
#  'PLUS_DI',
#  'PLUS_DM',
#  'PPO',
#  'ROC',
#  'ROCP',
#  'ROCR',
#  'ROCR100',
#  'RSI',
#  'STOCH',
#  'STOCHF',
#  'STOCHRSI',
#  'TRIX',
#  'ULTOSC',
#  'WILLR',
#  'BBANDS',
#  'DEMA',
#  'EMA',
#  'HT_TRENDLINE',
#  'KAMA',
#  'MA',
#  'MAMA',
#  'MAVP',
#  'MIDPOINT',
#  'MIDPRICE',
#  'SAR',
#  'SAREXT',
#  'SMA',
#  'T3',
#  'TEMA',
#  'TRIMA',
#  'WMA',
#  'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
# ...

# %%
# ?talib.MACD
# Out:
# Docstring:
# MACD(real[, fastperiod=?, slowperiod=?, signalperiod=?])
#
# Moving Average Convergence/Divergence (Momentum Indicators)
#
# Inputs:
#     real: (any ndarray)
# Parameters:
#     fastperiod: 12
#     slowperiod: 26
#     signalperiod: 9
# Outputs:
#     macd
#     macdsignal
#     macdhist
# Type:      function

# %%
# ?talib.CDLENGULFING
# Out:
# Docstring:
# CDLENGULFING(open, high, low, close)
#
# Engulfing Pattern (Pattern Recognition)
#
# Inputs:
#     prices: ['open', 'high', 'low', 'close']
# Outputs:
#     integer (values are -100, 0 or 100)
# Type:      function

# %%
data['Engulfing']=talib.CDLENGULFING(data['Open'],data['High'],data['Low'],data['Close'])

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-02-01  2408.000000  2420.600098  2347.100098  2378.699951  2371.559814
# 2022-02-02  2407.000000  2407.000000  2375.100098  2383.550049  2376.395264
# 2022-02-03  2392.000000  2401.449951  2347.199951  2352.750000  2345.687744
# 2022-02-04  2341.000000  2348.449951  2321.100098  2331.300049  2324.302246
# 2022-02-07  2342.000000  2356.800049  2305.000000  2317.100098  2310.144775
# ...                 ...          ...          ...          ...          ...
# 2023-01-12  2524.850098  2532.500000  2465.000000  2471.600098  2471.600098
# 2023-01-13  2458.399902  2472.899902  2434.600098  2467.600098  2467.600098
# 2023-01-16  2472.699951  2479.649902  2427.000000  2444.100098  2444.100098
# 2023-01-17  2458.000000  2483.000000  2450.600098  2478.800049  2478.800049
# 2023-01-18  2473.500000  2491.100098  2460.350098  2474.699951  2474.699951
#
#              Volume
# Date
# 2022-02-01  6092033
# ...

# %%
data
# Out:
#                  Open        High        Low       Close   Adj Close  \
# Date
# 2022-01-03  69.916664   70.733330  69.833336   70.416664   69.004890
# 2022-01-04  70.833336   73.016663  70.400002   72.050003   70.605484
# 2022-01-05  71.916664   72.300003  70.866669   71.099998   69.674538
# 2022-01-06  70.333336   71.050003  70.199997   70.633331   69.217216
# 2022-01-07  70.633331   71.316666  69.166664   69.349998   67.959618
# ...               ...         ...        ...         ...         ...
# 2022-12-26  96.599998   99.849998  94.650002   99.250000   99.250000
# 2022-12-27  99.800003  100.949997  98.400002  100.250000  100.250000
# 2022-12-28  99.599998  100.900002  99.250000   99.750000   99.750000
# 2022-12-29  98.500000   99.800003  98.300003   98.900002   98.900002
# 2022-12-30  99.400002  101.349998  99.250000   99.900002   99.900002
#
#               Volume  SMA_100
# Date
# 2022-01-03   8974341      NaN
# 2022-01-04  31336737      NaN
# 2022-01-05  11957511      NaN
# ...

# %%
pattern_function = getattr(talib,'CDLDOJI')
results=pattern_function(data['Open'],data['High'], data['Low'], data['Close'])

# %%
last = results.tail(1).values[0]

if last > 0:
    print( 'bullish')
elif last < 0:
    print('bearish')
else:
    print('nothing')
# Out:
# bullish

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import plotly.graph_objects as go

# %%
df= yf.download('BEL.NS',start='2022-6-1',end='2023-1-20')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df['Date']=df.index

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-06-01   78.449997   82.566666   78.250000   82.033333   81.587738
# 2022-06-02   82.733330   83.183334   81.383331   81.916664   81.471710
# 2022-06-03   82.333336   82.650002   80.583336   80.750000   80.311378
# 2022-06-06   80.300003   81.783333   79.433334   81.133331   80.692627
# 2022-06-07   82.000000   82.849998   80.716667   81.933334   81.488289
# ...                ...         ...         ...         ...         ...
# 2023-01-13   99.500000  100.099998   97.400002   99.949997   99.949997
# 2023-01-16  100.449997  103.000000  100.199997  102.099998  102.099998
# 2023-01-17  102.349998  103.000000  101.500000  102.900002  102.900002
# 2023-01-18  103.099998  104.000000  102.099998  102.699997  102.699997
# 2023-01-19  102.000000  103.000000  101.849998  102.849998  102.849998
#
#               Volume       Date
# Date
# 2022-06-01  34360020 2022-06-01
# 2022-06-02  26049855 2022-06-02
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

# %%
fig.show()

# %%
fig.write_image('/media/nikitha/Data/DBMS project/images/{}.webp'.format('BEL'))

# %%
pip install -U kaleido
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mplfinance
# Out:
# ...
#   Using cached mplfinance-0.12.9b7-py3-none-any.whl (73 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mplfinance as mpf

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_61710/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
mpf.plot(df,type="candle",style="yahoo",volume=True,mav=(25,50),figratio=(10,4))

# %%
import talib

# %%
df['ema25']=talib.EMA(df['Close'],25)
df['sma25']=talib.SMA(df['Close'],25)
sma=mpf.make_addplot(df['sma25'],color='lime',width=1.5)
ema=mpf.make_addplot(df['ema25'],color='purple',width=1.5)
mpf.plot(df,type="candle",style="yahoo",addplot=[sma,ema],mav=(10,20),volume=True,figratio=(10,6),savefig='/media/nikitha/Data/DBMS project/images/bel.png')

# %%
type(df['Date'])
# Out:
# pandas.core.series.Series
